# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, ttest_rel, wilcoxon, probplot

from IPython.display import display, HTML

# %% [markdown]
# # Import Raw Dataset

# %%
# Use your own csv data file.
DATASET_NAME = 'Foodweb'
# DATASET_NAME = 'Energy'

# If with missing scores, run the Impute notebook and use the new csv

df_Scores = pd.read_csv(f'Datasets/{DATASET_NAME}.csv', index_col=0)
df_Scores = df_Scores.fillna(0)


df_Scores['Difference'] = df_Scores['Posttest'] - df_Scores['Pretest']  
df_Scores
# Out:
#           Sex  Age  Grade       Class  IsSecondTime  Pretest  Posttest  Diff  \
# Surname
# Apresto     F   10      4     Maginoo           0.0        6         0    -6
# Bargo       F   10      5   Mapitagan           0.0        9        16     7
# Bernando    M    9      4    Magiting           0.0        4         4     0
# Callos      F   11      6      Mayumi           0.0        2         6     4
# Capillano   F   11      6    Marangal           0.0        0         0     0
# Galan       F   12      6    Marangal           1.0        6         5    -1
# Gonzaga     M   11      6    Marangal           1.0        7        11     4
# Helig       F    8      4     Matapat           0.0        4         1    -3
# Hermano     F   11      6      Mayumi           1.0        2         3     1
# Loyola      F    9      5  Mapagmahal           0.0        8        15     7
# Malabriga   F   11      4     Maginoo           0.0        1         1     0
# Mendoza     M    9      5  Mapagmahal           0.0        9         4    -5
# Nera        M   11      6      Mayumi           1.0        2         4     2
# Parame      M   10      4    Magiting           0.0        3         1    -2
# Tolentino   M    9      5   Mapitagan           0.0       12        12     0
#
#            Difference
# Surname
# Apresto            -6
# Bargo               7
# Bernando            0
# Callos              4
# Capillano           0
# Galan              -1
# Gonzaga             4
# Helig              -3
# Hermano             1
# Loyola              7
# Malabriga           0
# Mendoza            -5
# Nera                2
# Parame             -2
# Tolentino           0

# %% [markdown]
# ## [EDIT] Drop Outliers and Withdrawn

# %%
df_Scores = df_Scores.drop('Capillano')

# %% [markdown]
# # Pipeline
#
# 1. Determine Normality of Delta Score between Pretest and Postest
#     1. If normal, use `paired t-test` to measure significant difference from mean.
#     2. Else, use `wilcoxon` to measure significant difference from median.
# 2. Evaluate p_value
#     1. Significant change if p < threshold (0.05)
# 3. Evaluate effect
#     1. If normal, use `Cohen's D`.
#     2. Else, use `Rank-biserial correlation`.

# %%
df_Scores.describe()
# Out:
#              Age      Grade  IsSecondTime    Pretest   Posttest       Diff  \
# count  14.000000  14.000000     14.000000  14.000000  14.000000  14.000000
# mean   10.071429   5.000000      0.285714   5.357143   5.928571   0.571429
# std     1.141139   0.877058      0.468807   3.319109   5.370350   3.975198
# min     8.000000   4.000000      0.000000   1.000000   0.000000  -6.000000
# 25%     9.000000   4.000000      0.000000   2.250000   1.500000  -1.750000
# 50%    10.000000   5.000000      0.000000   5.000000   4.000000   0.000000
# 75%    11.000000   6.000000      0.750000   7.750000   9.750000   3.500000
# max    12.000000   6.000000      1.000000  12.000000  16.000000   7.000000
#
#        Difference
# count   14.000000
# mean     0.571429
# std      3.975198
# min     -6.000000
# 25%     -1.750000
# 50%      0.000000
# 75%      3.500000
# max      7.000000

# %% [markdown]
# # Inspect Normality Distribution

# %% [markdown]
# ## A. Graphical Approach

# %%
def DoBoxPlot(df, title_prefix : str):
    cols = ['Pretest','Posttest', 'Difference']
    plt.boxplot(df[cols])
    plt.title(f"{DATASET_NAME} - Box Plot of {title_prefix} Scores")
    plt.xticks(ticks=np.arange(1, len(cols) + 1), labels=cols, rotation=0)
    plt.ylabel("Value")
    # plt.ylim(-20, 20)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'Graphs/{DATASET_NAME} - {title_prefix} Box Plot of Scores.png')
    
    plt.show()

# %% [markdown]
# ### Distribution Curve
# Check for symmetry and center.

# %%
def DoHistPlot(df, title_prefix : str):
    plt.hist(df['Difference'], bins=20)
    plt.title(f'{DATASET_NAME} - {title_prefix} Score Difference Distribution')
    plt.xlabel('Score Difference')
    plt.ylabel('Frequency')

    plt.xticks(rotation=0)
    plt.tight_layout()
    
    plt.savefig(f'Graphs/{DATASET_NAME} - {title_prefix} Hist Score Distribution.png')
    plt.show()

# %% [markdown]
# ### Q-Q Plot
# Check if values land precisely on the line.

# %%
def DoQQPlot(df, title_prefix : str):
    probplot(df.Difference, dist="norm", plot=plt)
    plt.title(f"{DATASET_NAME} - Q-Q Plot of {title_prefix} Score Difference")
    plt.xlabel("Theoretical Quantiles")
    plt.ylabel("Sample Quantiles")
    plt.grid(True)
    plt.savefig(f'Graphs/{DATASET_NAME} - QQ Plot of {title_prefix} Score Difference.png')
    plt.show()

# %% [markdown]
# ## B. Statistical Approach
# ### Shapiro for n <= 20
#
# Null Hypothesis is that it's Normal

# %%
def EvaluateDataset(df):
    res = {}

    res['Avg Difference'] = df.Difference.mean()
    res['Variance'] = df.Difference.std()
    
    shapiro_result = shapiro(df.Difference)
    
    display(HTML("<b>Computing Normality.</b><br><i>Is distribution Parametric?</i><br><br>"))
    display(HTML(f"<b>Shapiro Wilk Test p : {shapiro_result.pvalue:.4f}</b>"))

    res['Sample size'] = df.shape[0]
    res['Shapiro W'] = shapiro_result.statistic
    res['Shapiro p'] = shapiro_result.pvalue

    # CORRECTION: Shapiro's null is that it is NOT Normal
    res['IsParametric'] = shapiro_result.pvalue > 0.05 and df.shape[0] >= 10


    # Test's null is that it is NOT significant
    if res['IsParametric']:
        display(HTML("<br><b>Using 2 Tailed for Significance & Cohen D for effect</b><br>"))
        
        result = ttest_rel(df.Pretest, df.Posttest)
        display(HTML(f"<b>2 Tailed T test p: {result.pvalue:4f}</b><br>"))
        
        cohens_d = df.Difference.mean() / df.Difference.std()
        display(HTML(f"<b>Cohen's D: {cohens_d:4f}</b><br>"))
        
        res["Two tailed t-test p-value"] = result.pvalue
        res["Cohen's D"] = cohens_d 

    else:
        display(HTML("<br><b>Using Wilcoxon for Significance & Biserial for effect</b><br><br>"))
        
        result = wilcoxon(df.Difference)
        display(HTML(f"<b>Wilcoxon p: {result.pvalue:4f}</b><br>"))
    
        W = result.statistic
        n = df.shape[0]
        rb_corr = 1 - (2 * W) / (n * (n + 1) / 2)
        
        display(HTML(f"<b>Rank-biserial correlation: {rb_corr:.4f}</b><br>"))

        res['Wilcoxon p-value'] = result.pvalue
        res['Rank-biserial correlation'] = rb_corr 

    return res

# %%
res_List = []


cluster = [
    {
        'name' : "All",
        'df' : df_Scores
    },
    {
        'name' : "Grade 4",
        'df' : df_Scores[df_Scores['Grade'] == 4]
    },
    {
        'name' : "Grade 5",
        'df' : df_Scores[df_Scores['Grade'] == 5]
    },
    {
        'name' : "Grade 6",
        'df' : df_Scores[df_Scores['Grade'] == 6]
    },
]


for item in cluster:
    DoBoxPlot(item['df'], item['name'])
    DoHistPlot(item['df'], item['name'])
    DoQQPlot(item['df'], item['name'])
    res_List.append({
            'Cluster': item['name'], **EvaluateDataset(item['df'])
        }
    )

pd.DataFrame(res_List)
# Out:
# <b>Computing Normality.</b><br><i>Is distribution Parametric?</i><br><br>
# <b>Shapiro Wilk Test p : 0.7512</b>
# <br><b>Using 2 Tailed for Significance & Cohen D for effect</b><br>
# <b>2 Tailed T test p: 0.599763</b><br>
# <b>Cohen's D: 0.143748</b><br>
# <b>Computing Normality.</b><br><i>Is distribution Parametric?</i><br><br>
# <b>Shapiro Wilk Test p : 0.3842</b>
# <br><b>Using Wilcoxon for Significance & Biserial for effect</b><br><br>
# <b>Wilcoxon p: 0.250000</b><br>
# <b>Rank-biserial correlation: 1.0000</b><br>
# <b>Computing Normality.</b><br><i>Is distribution Parametric?</i><br><br>
# <b>Shapiro Wilk Test p : 0.2677</b>
# <br><b>Using Wilcoxon for Significance & Biserial for effect</b><br><br>
# <b>Wilcoxon p: 0.500000</b><br>
# <b>Rank-biserial correlation: 0.8000</b><br>
# <b>Computing Normality.</b><br><i>Is distribution Parametric?</i><br><br>
# <b>Shapiro Wilk Test p : 0.4677</b>
# <br><b>Using Wilcoxon for Significance & Biserial for effect</b><br><br>
# <b>Wilcoxon p: 0.187500</b><br>
# <b>Rank-biserial correlation: 0.8000</b><br>
#    Cluster  Avg Difference  Variance  Sample size  Shapiro W  Shapiro p  \
# 0      All        0.571429  3.975198           14   0.961715   0.751221
# 1  Grade 4       -2.200000  2.489980            5   0.895248   0.384181
# 2  Grade 5        2.250000  5.852350            4   0.862062   0.267658
# 3  Grade 6        2.000000  2.121320            5   0.910025   0.467739
#
#    IsParametric  Two tailed t-test p-value  Cohen's D  Wilcoxon p-value  \
# 0          True                   0.599763   0.143748               NaN
# 1         False                        NaN        NaN            0.2500
# 2         False                        NaN        NaN            0.5000
# 3         False                        NaN        NaN            0.1875
#
#    Rank-biserial correlation
# 0                        NaN
# 1                        1.0
# 2                        0.8
# 3                        0.8

# %% [markdown]
# # Interpret

# %% [markdown]
# ## Evaluate Significant Difference and Effect
#
# <table>
#     <tr>
#         <td></td>
#         <td><b>T-Test</b></td>
#         <td><b>Wilcoxon</b></td>
#     </tr>
#     <tr>
#         <td><b>Sample size</b></td>
#         <td></td>
#         <td>N <= 20</td>
#     </tr>
#     <tr>
#         <td><b>Normal Distribution</b></td>
#         <td>✅</td>
#         <td>❌</td>
#     </tr>
#     <tr>
#         <td><b>Signinifigance</b></td>
#         <td>Mean</td>
#         <td>Median</td>
#     </tr>
#     <tr>
#         <td><b>Effect Metric</b></td>
#         <td>Cohen's D</td>
#         <td>Rank-biserial Correlation</td>
#     </tr>
# </table>
#
# <br>
#
# <div align="center">
#     <h3>Cohen's D Interpretation</h3>
#     <img src='https://www.simplypsychology.org/wp-content/uploads/cohen-d.jpg' alt="Ranges"/>
#     <p>Negative magnitude indicates lower Posttest performance or Treatment has negative effect to X size</p>
# </div>

# %% [markdown]
# # EDA
# I highly discourage testing significance or effect in subgroups considering the sample sizes are insanely small representations of population.
#
# Use descriptive stats instead to see the difference between cases you discovered.

# %%
def DoBarComparisson(col : str):    
    df_Scores[[col, 'Pretest', 'Posttest']].groupby(col).mean().plot(kind='bar')
    
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.xticks(rotation=0)

    plt.title(f'{DATASET_NAME} - Avg Scores by {col}')
    plt.tight_layout()
    
    plt.savefig(f'Graphs/{DATASET_NAME} - Avg Scores by {col}.png')
    plt.show()


def DoPlotComparisson(col : str):    
    sns.scatterplot(df_Scores, x='Pretest', y='Posttest', hue=col, palette='viridis', alpha=0.5)    
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.grid(axis='x', linestyle='--', alpha=0.7)


    
    plt.title(f'{DATASET_NAME} - Scores by {col}')
    plt.tight_layout()
    plt.savefig(f'Graphs/{DATASET_NAME} - Scores by {col}.png')
    plt.show()

# %%
for col in ['Sex','Age', 'Grade', 'IsSecondTime']:
    DoBarComparisson(col)
    DoPlotComparisson(col)
